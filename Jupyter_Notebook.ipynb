# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Shelomita**

# %% [markdown]
# Preferably recognized as a human

# %% [markdown]
# *I started to fall in love with data science when I was 8 when I was watching a live quick count on the presidential vote,
# I used to wonder how they were able to gain insights from the limited data available.
# Turns out there is a wonderful world for a curious human like me.
# I really like how learning about data because it gives me a lot of information about the world in a tangible, quantifiable way.
# Now I aspire to be a junior data scientist and I'm currently a stat undergraduate in an Indonesian University.*

# %% [markdown]
# ### The code below generates 1000 random points from normal distribution and plots it

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm


x = np.random.randn(1000)

x_sorted = np.sort(x)
plt.figure(figsize=(7, 5))
plt.plot(x_sorted, norm.pdf(x_sorted))
plt.title("Normal distribution", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Normal distribution')

# %% [markdown]
# ***
# ### Things I have learned from IBM Data Science Coursera certification so far :
# ~how to be a sexy data scientist~
# 1. What is Data Science
#   * Data Science definition
#   * Data Science topics
#   * Data Science in business
# 2. Tools for Data Science
#   * Currently finishing
#
# ***
#
# |Lesson Part |Status |
# |:---: |:---:|
# |1 |Finished |
# |2 |Ongoing |
#
# ***
#
# Learn more about IBM Data Science certification here : [Coursera IBM Data Science](https://www.coursera.org/professional-certificates/ibm-data-science)

# %% [markdown]
# ###### Some wholesome meme for you~
# <img src="https://i.pinimg.com/736x/83/3c/52/833c520faf647c51744f7ae2fbe96f7c.jpg" alt="smiling doggo" height="150" width="150" />

# %% [markdown]
# ##### Thank you for reviewing my jupyter notebook practice! Hope you have a great day! Have fun learning ahead ^^
